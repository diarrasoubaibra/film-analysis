# %% [markdown]
# # Phase 2: Analyse des données

# %%
from ibmoviesdk import MovieClient, MovieConfig
# Out:
# c:\Users\diarr\OneDrive\Documents\film-analysis\env\Lib\site-packages\pydantic\_internal\_config.py:373: UserWarning: Valid config keys have changed in V2:
# * 'orm_mode' has been renamed to 'from_attributes'
#   warnings.warn(message, UserWarning)

# %%
config = MovieConfig(movie_base_url="https://data-movie-app-back.onrender.com")
client = MovieClient(config=config)

client.health_check()
# Out:
# MOVIE_API_BASE_URL in MovieConfig init: https://data-movie-app-back.onrender.com
# {'message': 'API MovieLens Opérationnelle'}

# %%
movie = client.get_movie(20)
print(f"Titre : {movie.title}")
print(f"Genre: {movie.genres}")
# Out:
# Titre : Money Train (1995)
# Genre: Action|Comedy|Crime|Drama|Thriller

# %%
ratings_df = client.list_ratings(limit=10, output_format="pandas")
ratings_df.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
ratings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   userId     10 non-null     int64
#  1   movieId    10 non-null     int64
#  2   rating     10 non-null     float64
#  3   timestamp  10 non-null     int64
# dtypes: float64(1), int64(3)
# memory usage: 452.0 bytes

# %%
analytics = client.get_analytics()
print(analytics)
# Out:
# movie_count=9742 rating_count=100836 tag_count=100836 link_count=9742

# %%
import time
import pandas as pd


total_ratings = client.get_analytics().rating_count
batch_size = 1000
all_ratings = []

for skip in range(0, total_ratings, batch_size):
    print(f"Fetching ratings from {skip} to {skip + batch_size}")
    batch_df  = client.list_ratings(limit=batch_size, skip=skip, output_format="pandas")
    all_ratings.append(batch_df)
    time.sleep(0.5)  # To avoid hitting the rate limit
    complete_ratings_df = pd.concat(all_ratings, ignore_index=True)
    # complete_ratings_df
# Out:
# Fetching ratings from 0 to 1000
# Fetching ratings from 1000 to 2000
# Fetching ratings from 2000 to 3000
# Fetching ratings from 3000 to 4000
# Fetching ratings from 4000 to 5000
# Fetching ratings from 5000 to 6000
# Fetching ratings from 6000 to 7000
# Fetching ratings from 7000 to 8000
# Fetching ratings from 8000 to 9000
# Fetching ratings from 9000 to 10000
# Fetching ratings from 10000 to 11000
# Fetching ratings from 11000 to 12000
# Fetching ratings from 12000 to 13000
# Fetching ratings from 13000 to 14000
# Fetching ratings from 14000 to 15000
# Fetching ratings from 15000 to 16000
# Fetching ratings from 16000 to 17000
# Fetching ratings from 17000 to 18000
# Fetching ratings from 18000 to 19000
# Fetching ratings from 19000 to 20000
# Fetching ratings from 20000 to 21000
# Fetching ratings from 21000 to 22000
# Fetching ratings from 22000 to 23000
# Fetching ratings from 23000 to 24000
# Fetching ratings from 24000 to 25000
# Fetching ratings from 25000 to 26000
# Fetching ratings from 26000 to 27000
# Fetching ratings from 27000 to 28000
# Fetching ratings from 28000 to 29000
# Fetching ratings from 29000 to 30000
# Fetching ratings from 30000 to 31000
# Fetching ratings from 31000 to 32000
# Fetching ratings from 32000 to 33000
# Fetching ratings from 33000 to 34000
# Fetching ratings from 34000 to 35000
# Fetching ratings from 35000 to 36000
# Fetching ratings from 36000 to 37000
# Fetching ratings from 37000 to 38000
# Fetching ratings from 38000 to 39000
# Fetching ratings from 39000 to 40000
# Fetching ratings from 40000 to 41000
# Fetching ratings from 41000 to 42000
# Fetching ratings from 42000 to 43000
# Fetching ratings from 43000 to 44000
# Fetching ratings from 44000 to 45000
# Fetching ratings from 45000 to 46000
# Fetching ratings from 46000 to 47000
# Fetching ratings from 47000 to 48000
# Fetching ratings from 48000 to 49000
# Fetching ratings from 49000 to 50000
# Fetching ratings from 50000 to 51000
# Fetching ratings from 51000 to 52000
# Fetching ratings from 52000 to 53000
# Fetching ratings from 53000 to 54000
# Fetching ratings from 54000 to 55000
# Fetching ratings from 55000 to 56000
# Fetching ratings from 56000 to 57000
# Fetching ratings from 57000 to 58000
# Fetching ratings from 58000 to 59000
# Fetching ratings from 59000 to 60000
# Fetching ratings from 60000 to 61000
# Fetching ratings from 61000 to 62000
# Fetching ratings from 62000 to 63000
# Fetching ratings from 63000 to 64000
# Fetching ratings from 64000 to 65000
# Fetching ratings from 65000 to 66000
# Fetching ratings from 66000 to 67000
# Fetching ratings from 67000 to 68000
# Fetching ratings from 68000 to 69000
# Fetching ratings from 69000 to 70000
# Fetching ratings from 70000 to 71000
# Fetching ratings from 71000 to 72000
# Fetching ratings from 72000 to 73000
# Fetching ratings from 73000 to 74000
# Fetching ratings from 74000 to 75000
# Fetching ratings from 75000 to 76000
# Fetching ratings from 76000 to 77000
# Fetching ratings from 77000 to 78000
# Fetching ratings from 78000 to 79000
# Fetching ratings from 79000 to 80000
# Fetching ratings from 80000 to 81000
# Fetching ratings from 81000 to 82000
# Fetching ratings from 82000 to 83000
# Fetching ratings from 83000 to 84000
# Fetching ratings from 84000 to 85000
# Fetching ratings from 85000 to 86000
# Fetching ratings from 86000 to 87000
# Fetching ratings from 87000 to 88000
# Fetching ratings from 88000 to 89000
# Fetching ratings from 89000 to 90000
# Fetching ratings from 90000 to 91000
# Fetching ratings from 91000 to 92000
# Fetching ratings from 92000 to 93000
# Fetching ratings from 93000 to 94000
# Fetching ratings from 94000 to 95000
# Fetching ratings from 95000 to 96000
# Fetching ratings from 96000 to 97000
# Fetching ratings from 97000 to 98000
# Fetching ratings from 98000 to 99000
# Fetching ratings from 99000 to 100000
# Fetching ratings from 100000 to 101000

# %%
# Concatenate all the batches into a single DataFrame
complete_ratings_df = pd.concat(all_ratings, ignore_index=True)
complete_ratings_df
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
rating_per_user = complete_ratings_df['userId'].value_counts().rename_axis('userId').reset_index(name='rating_count')
rating_per_user
# Out:
#      userId  rating_count
# 0       414          2698
# 1       599          2478
# 2       474          2108
# 3       448          1864
# 4       274          1346
# ..      ...           ...
# 605     442            20
# 606     278            20
# 607     147            20
# 608     320            20
# 609      53            20
#
# [610 rows x 2 columns]

# %%
total_ratings = client.get_analytics().rating_count
batch_size = 1000

from collections import defaultdict
user_rating_counts = defaultdict(int)

for skip in range(0, total_ratings, batch_size):
    print(f"Fetching ratings from {skip} to {skip + batch_size}...")
    batch_df  = client.list_ratings(limit=batch_size, skip=skip, output_format="pandas")
    
    batch_countS = batch_df['userId'].value_counts()


    for user_id, count in batch_countS.items():
        user_rating_counts[user_id] += count

    time.sleep(0.5)  # To avoid hitting the rate limit
# Convert the defaultdict to a DataFrame
rating_per_user = pd.DataFrame(list(user_rating_counts.items()), columns=['userId', 'rating_count'])
rating_per_user
# Out:
# Fetching ratings from 0 to 1000...
# Fetching ratings from 1000 to 2000...
# Fetching ratings from 2000 to 3000...
# Fetching ratings from 3000 to 4000...
# Fetching ratings from 4000 to 5000...
# Fetching ratings from 5000 to 6000...
# Fetching ratings from 6000 to 7000...
# Fetching ratings from 7000 to 8000...
# Fetching ratings from 8000 to 9000...
# Fetching ratings from 9000 to 10000...
# Fetching ratings from 10000 to 11000...
# Fetching ratings from 11000 to 12000...
# Fetching ratings from 12000 to 13000...
# Fetching ratings from 13000 to 14000...
# Fetching ratings from 14000 to 15000...
# Fetching ratings from 15000 to 16000...
# Fetching ratings from 16000 to 17000...
# Fetching ratings from 17000 to 18000...
# Fetching ratings from 18000 to 19000...
# Fetching ratings from 19000 to 20000...
# Fetching ratings from 20000 to 21000...
# Fetching ratings from 21000 to 22000...
# Fetching ratings from 22000 to 23000...
# Fetching ratings from 23000 to 24000...
# Fetching ratings from 24000 to 25000...
# Fetching ratings from 25000 to 26000...
# Fetching ratings from 26000 to 27000...
# Fetching ratings from 27000 to 28000...
# Fetching ratings from 28000 to 29000...
# Fetching ratings from 29000 to 30000...
# Fetching ratings from 30000 to 31000...
# Fetching ratings from 31000 to 32000...
# Fetching ratings from 32000 to 33000...
# Fetching ratings from 33000 to 34000...
# Fetching ratings from 34000 to 35000...
# Fetching ratings from 35000 to 36000...
# Fetching ratings from 36000 to 37000...
# Fetching ratings from 37000 to 38000...
# Fetching ratings from 38000 to 39000...
# Fetching ratings from 39000 to 40000...
# Fetching ratings from 40000 to 41000...
# Fetching ratings from 41000 to 42000...
# Fetching ratings from 42000 to 43000...
# Fetching ratings from 43000 to 44000...
# Fetching ratings from 44000 to 45000...
# Fetching ratings from 45000 to 46000...
# Fetching ratings from 46000 to 47000...
# Fetching ratings from 47000 to 48000...
# Fetching ratings from 48000 to 49000...
# Fetching ratings from 49000 to 50000...
# Fetching ratings from 50000 to 51000...
# Fetching ratings from 51000 to 52000...
# Fetching ratings from 52000 to 53000...
# Fetching ratings from 53000 to 54000...
# Fetching ratings from 54000 to 55000...
# Fetching ratings from 55000 to 56000...
# Fetching ratings from 56000 to 57000...
# Fetching ratings from 57000 to 58000...
# Fetching ratings from 58000 to 59000...
# Fetching ratings from 59000 to 60000...
# Fetching ratings from 60000 to 61000...
# Fetching ratings from 61000 to 62000...
# Fetching ratings from 62000 to 63000...
# Fetching ratings from 63000 to 64000...
# Fetching ratings from 64000 to 65000...
# Fetching ratings from 65000 to 66000...
# Fetching ratings from 66000 to 67000...
# Fetching ratings from 67000 to 68000...
# Fetching ratings from 68000 to 69000...
# Fetching ratings from 69000 to 70000...
# Fetching ratings from 70000 to 71000...
# Fetching ratings from 71000 to 72000...
# Fetching ratings from 72000 to 73000...
# Fetching ratings from 73000 to 74000...
# Fetching ratings from 74000 to 75000...
# Fetching ratings from 75000 to 76000...
# Fetching ratings from 76000 to 77000...
# Fetching ratings from 77000 to 78000...
# Fetching ratings from 78000 to 79000...
# Fetching ratings from 79000 to 80000...
# Fetching ratings from 80000 to 81000...
# Fetching ratings from 81000 to 82000...
# Fetching ratings from 82000 to 83000...
# Fetching ratings from 83000 to 84000...
# Fetching ratings from 84000 to 85000...
# Fetching ratings from 85000 to 86000...
# Fetching ratings from 86000 to 87000...
# Fetching ratings from 87000 to 88000...
# Fetching ratings from 88000 to 89000...
# Fetching ratings from 89000 to 90000...
# Fetching ratings from 90000 to 91000...
# Fetching ratings from 91000 to 92000...
# Fetching ratings from 92000 to 93000...
# Fetching ratings from 93000 to 94000...
# Fetching ratings from 94000 to 95000...
# Fetching ratings from 95000 to 96000...
# Fetching ratings from 96000 to 97000...
# Fetching ratings from 97000 to 98000...
# Fetching ratings from 98000 to 99000...
# Fetching ratings from 99000 to 100000...
# Fetching ratings from 100000 to 101000...
#      userId  rating_count
# 0         6           314
# 1         1           232
# 2         4           216
# 3         7           152
# 4         5            44
# ..      ...           ...
# 605     604           100
# 606     608           831
# 607     607           187
# 608     610          1302
# 609     609            37
#
# [610 rows x 2 columns]

# %%
# trier les utilisateurs par le nombre de notes
rating_per_user = rating_per_user.sort_values(by='rating_count', ascending=False)
# afficher les 10 utilisateurs ayant le plus de notes
top_10_users = rating_per_user.head(10)
print(top_10_users)
# Out:
#      userId  rating_count
# 410     414          2698
# 597     599          2478
# 471     474          2108
# 438     448          1864
# 268     274          1346
# 608     610          1302
# 66       68          1260
# 373     380          1218
# 603     606          1115
# 287     288          1055

# %% [markdown]
# ## Question Business pertinentes

# %% [markdown]
# ## Quels genres de films les utilisateurs taguent le plus positivement(note>=4)?

# %%
chunk_size = 1000
skip = 0
all_high_ratings = []

while True:
    chunk = client.list_ratings(
        skip=skip,
        limit=chunk_size,
        min_rating=4.0,
        output_format="pandas"
    )
    if chunk.empty:
        break

    all_high_ratings.append(chunk)
    skip += chunk_size
    time.sleep(0.5)  # To avoid hitting the rate limit

    high_rating_df = pd.concat(all_high_ratings, ignore_index=True)
    print(high_rating_df.shape)
    high_rating_df.head()
# Out:
# (1000, 4)
# (2000, 4)
# (3000, 4)
# (4000, 4)
# (5000, 4)
# (6000, 4)
# (7000, 4)
# (8000, 4)
# (9000, 4)
# (10000, 4)
# (11000, 4)
# (12000, 4)
# (13000, 4)
# (14000, 4)
# (15000, 4)
# (16000, 4)
# (17000, 4)
# (18000, 4)
# (19000, 4)
# (20000, 4)
# (21000, 4)
# (22000, 4)
# (23000, 4)
# (24000, 4)
# (25000, 4)
# (26000, 4)
# (27000, 4)
# (28000, 4)
# (29000, 4)
# (30000, 4)
# (31000, 4)
# (32000, 4)
# (33000, 4)
# (34000, 4)
# (35000, 4)
# (36000, 4)
# (37000, 4)
# (38000, 4)
# (39000, 4)
# (40000, 4)
# (41000, 4)
# (42000, 4)
# (43000, 4)
# (44000, 4)
# (45000, 4)
# (46000, 4)
# (47000, 4)
# (48000, 4)
# (48580, 4)

# %%
# Supprimer les doublons
user_movie_pairs = high_rating_df[['userId', 'movieId']].drop_duplicates()
user_movie_pairs
# Out:
#        userId  movieId
# 0           1        1
# 1           1        3
# 2           1        6
# 3           1       47
# 4           1       50
# ...       ...      ...
# 48575     610   166528
# 48576     610   166534
# 48577     610   168248
# 48578     610   168250
# 48579     610   168252
#
# [48580 rows x 2 columns]

# %%
# Récupérer tous les tags correspondant aux paires utilisateur-film

all_tags = []
chunk_size = 1000
skip = 0

while True:
    tag_chunk = client.list_tags(skip=skip, limit=chunk_size, output_format="pandas")
    if tag_chunk.empty:
        break
    all_tags.append(tag_chunk)
    skip += chunk_size
    time.sleep(0.5)  # To avoid hitting the rate limit
    all_tags_df = pd.concat(all_tags, ignore_index=True)

    all_tags_df

# %%
tagged_high_ratings = pd.merge(
    user_movie_pairs,
    all_tags_df,
    on=['userId', 'movieId'])
print(tagged_high_ratings.shape)
tagged_high_ratings.head()
# Out:
# (2378, 4)
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992
# 3       2    89774     Boxing story  1445715207
# 4       2    89774              MMA  1445715200

# %%
# Récupérer les genres des films

def get_movie_genres(movie_id):
    try:
        movie = client.get_movie(movie_id)
        return movie.genres
    except Exception as e:
        print(f"Error fetching genres for movie {movie_id}: {e}")
        return ""

# Appliquer uniquement aux movieId uniques qu'on a dans tagged_high_ratings
unique_movie_ids = tagged_high_ratings['movieId'].unique()

movie_genres = {
    movie_id: get_movie_genres(movie_id) for movie_id in unique_movie_ids
}

# " Ajoutons la colonne genres à tagged_high_ratings"
tagged_high_ratings['genres'] = tagged_high_ratings['movieId'].map(movie_genres)
print(tagged_high_ratings.shape)
tagged_high_ratings
# Out:
# (2378, 5)
#       userId  movieId               tag   timestamp  \
# 0          2    60756             funny  1445714994
# 1          2    60756   Highly quotable  1445714996
# 2          2    60756      will ferrell  1445714992
# 3          2    89774      Boxing story  1445715207
# 4          2    89774               MMA  1445715200
# ...      ...      ...               ...         ...
# 2373     606     6107      World War II  1178473747
# 2374     606     7382         for katie  1171234019
# 2375     610     3265            gun fu  1493843984
# 2376     610     3265  heroic bloodshed  1493843978
# 2377     610   168248  Heroic Bloodshed  1493844270
#
#                            genres
# 0                          Comedy
# 1                          Comedy
# 2                          Comedy
# 3                           Drama
# 4                           Drama
# ...                           ...
# 2373                    Drama|War
# 2374       Drama|Mystery|Thriller
# 2375  Action|Crime|Drama|Thriller
# 2376  Action|Crime|Drama|Thriller
# 2377        Action|Crime|Thriller
#
# [2378 rows x 5 columns]

# %%
tagged_high_ratings
# Out:
#       userId  movieId               tag   timestamp  \
# 0          2    60756             funny  1445714994
# 1          2    60756   Highly quotable  1445714996
# 2          2    60756      will ferrell  1445714992
# 3          2    89774      Boxing story  1445715207
# 4          2    89774               MMA  1445715200
# ...      ...      ...               ...         ...
# 2373     606     6107      World War II  1178473747
# 2374     606     7382         for katie  1171234019
# 2375     610     3265            gun fu  1493843984
# 2376     610     3265  heroic bloodshed  1493843978
# 2377     610   168248  Heroic Bloodshed  1493844270
#
#                            genres
# 0                          Comedy
# 1                          Comedy
# 2                          Comedy
# 3                           Drama
# 4                           Drama
# ...                           ...
# 2373                    Drama|War
# 2374       Drama|Mystery|Thriller
# 2375  Action|Crime|Drama|Thriller
# 2376  Action|Crime|Drama|Thriller
# 2377        Action|Crime|Thriller
#
# [2378 rows x 5 columns]

# %%
# Aggregation finale: genre, tag count

# separer les genres en plusieurs lignes s'ils sont séparés par "|"
tagged_high_ratings['genres'] = tagged_high_ratings['genres'].str.split('|')
tagged_exploded = tagged_high_ratings.explode('genres')

tagged_exploded
# Out:
#       userId  movieId               tag   timestamp    genres
# 0          2    60756             funny  1445714994    Comedy
# 1          2    60756   Highly quotable  1445714996    Comedy
# 2          2    60756      will ferrell  1445714992    Comedy
# 3          2    89774      Boxing story  1445715207     Drama
# 4          2    89774               MMA  1445715200     Drama
# ...      ...      ...               ...         ...       ...
# 2376     610     3265  heroic bloodshed  1493843978     Drama
# 2376     610     3265  heroic bloodshed  1493843978  Thriller
# 2377     610   168248  Heroic Bloodshed  1493844270    Action
# 2377     610   168248  Heroic Bloodshed  1493844270     Crime
# 2377     610   168248  Heroic Bloodshed  1493844270  Thriller
#
# [6664 rows x 5 columns]

# %%
# compter les combianaisons genre-tag
genre_tag_counts = (
     tagged_exploded
     .groupby(['genres', 'tag'])
     .size()
     .reset_index(name='count')
     .sort_values(by='count', ascending=False)
)

genre_tag_counts
# Out:
#         genres               tag  count
# 1971     Drama  In Netflix queue     20
# 2159     Drama       atmospheric     19
# 4321  Thriller      twist ending     16
# 3280   Mystery      twist ending     14
# 4304  Thriller          suspense     14
# ...        ...               ...    ...
# 18      Action              Borg      1
# 17      Action       Ben Stiller      1
# 4464   Western               oil      1
# 4463   Western             music      1
# 4462   Western          morality      1
#
# [4472 rows x 3 columns]
